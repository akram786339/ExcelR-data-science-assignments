# %%
import pandas as pd
import numpy as np
import dataframe as df
import pyramidarima as pmdarima
import autoregressive integrated moving average as ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (20,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid')
# %matplotlib inline
# Out:
#   Cell In[12], line 5
#     import autoregressive integrated moving average as ARIMA
#                           ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("C:\\Users\\Akram siddiqui\\documents\\ExcelR\\Data science assignments\\Timeseries\\exchange_rate.csv", index_col=0, parse_dates=True)
df
# Out:
#                    Ex_rate
# date
# 01-01-1990 00:00  0.785500
# 02-01-1990 00:00  0.781800
# 03-01-1990 00:00  0.786700
# 04-01-1990 00:00  0.786000
# 05-01-1990 00:00  0.784900
# ...                    ...
# 06-10-2010 00:00  0.718494
# 07-10-2010 00:00  0.721839
# 08-10-2010 00:00  0.723197
# 09-10-2010 00:00  0.720825
# 10-10-2010 00:00  0.720825
#
# [7588 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
adfuller(df['Ex_rate'])[1]
# Out:
# 0.44923273535982894

# %%
df.isna().sum()
# Out:
# Ex_rate    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2258

# %%
order = auto_arima(df['Ex_rate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 order = auto_arima(df['Ex_rate'])
#
# NameError: name 'auto_arima' is not defined

# %%
import order as auto_arima
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import order as auto_arima
#
# ModuleNotFoundError: No module named 'order'

# %%
df.shape
# Out:
# (7588, 1)

# %%
#Split the data
train = df.iloc[:-30]
test = df.iloc[-30:]

# %%
train.shape
# Out:
# (7558, 1)

# %%
train
# Out:
#                    Ex_rate
# date
# 01-01-1990 00:00  0.785500
# 02-01-1990 00:00  0.781800
# 03-01-1990 00:00  0.786700
# 04-01-1990 00:00  0.786000
# 05-01-1990 00:00  0.784900
# ...                    ...
# 06-09-2010 00:00  0.747831
# 07-09-2010 00:00  0.746436
# 08-09-2010 00:00  0.738662
# 09-09-2010 00:00  0.741125
# 10-09-2010 00:00  0.744546
#
# [7558 rows x 1 columns]

# %%
test.shape
# Out:
# (30, 1)

# %% [markdown]
# # ARIMA Model

# %%
model = ARIMA(train['Ex_rate'], order=(1, 0, 5)).fit()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
test
# Out:
#                    Ex_rate
# date
# 11-09-2010 00:00  0.745796
# 12-09-2010 00:00  0.745045
# 13-09-2010 00:00  0.747692
# 14-09-2010 00:00  0.745601
# 15-09-2010 00:00  0.747680
# 16-09-2010 00:00  0.744602
# 17-09-2010 00:00  0.744158
# 18-09-2010 00:00  0.745184
# 19-09-2010 00:00  0.744990
# 20-09-2010 00:00  0.748951
# 21-09-2010 00:00  0.749681
# 22-09-2010 00:00  0.751654
# 23-09-2010 00:00  0.733999
# 24-09-2010 00:00  0.730567
# 25-09-2010 00:00  0.729714
# 26-09-2010 00:00  0.729714
# 27-09-2010 00:00  0.726533
# 28-09-2010 00:00  0.725058
# 29-09-2010 00:00  0.724506
# 30-09-2010 00:00  0.721553
# 01-10-2010 00:00  0.717618
# 02-10-2010 00:00  0.719114
# 03-10-2010 00:00  0.719114
# 04-10-2010 00:00  0.719735
# 05-10-2010 00:00  0.718701
# 06-10-2010 00:00  0.718494
# 07-10-2010 00:00  0.721839
# 08-10-2010 00:00  0.723197
# 09-10-2010 00:00  0.720825
# 10-10-2010 00:00  0.720825

# %%
train
# Out:
#                    Ex_rate
# date
# 01-01-1990 00:00  0.785500
# 02-01-1990 00:00  0.781800
# 03-01-1990 00:00  0.786700
# 04-01-1990 00:00  0.786000
# 05-01-1990 00:00  0.784900
# ...                    ...
# 06-09-2010 00:00  0.747831
# 07-09-2010 00:00  0.746436
# 08-09-2010 00:00  0.738662
# 09-09-2010 00:00  0.741125
# 10-09-2010 00:00  0.744546
#
# [7558 rows x 1 columns]

# %%
ypred = model.predict(start =1791, end = 1820)

# %%
print(np.sqrt(mean_squared_error(test['Ex_rate'], ypred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(np.sqrt(mean_squared_error(test['Ex_rate'], ypred)))
#
# NameError: name 'mean_squared_error' is not defined
