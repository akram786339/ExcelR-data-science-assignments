# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 200 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\Akram siddiqui\\documents\\ExcelR\\Data science assignments\\EDA1/Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df['DS'].unique()
# Out:
# array([ 0.00000000e+00, -1.79000000e-06,  3.66773608e-06,             nan,
#        -3.24000000e-06,  2.54296927e-06, -2.26000000e-06,  8.65602121e-07,
#         1.16544621e-06,  5.57785247e-07, -2.22000000e-06, -3.09000000e-06,
#        -2.52000000e-06, -3.27000000e-06,  6.32344823e-06, -1.09000000e-06,
#        -5.37000000e-06, -1.70000000e-06,  3.21484620e-06,  3.47927095e-06,
#        -4.21000000e-06,  1.04857389e-06,  2.70636000e-03, -8.96000000e-08,
#         1.39285783e-06, -3.98000000e-07, -4.76000000e-07,  3.55635347e-06,
#         4.07729571e-06,  3.72913403e-06, -2.61000000e-07,  6.18521847e-08,
#        -2.51000000e-06,  1.35429413e-08,  4.56585228e-06, -2.90000000e-06,
#        -2.50000000e-06, -2.05000000e-06, -1.35318000e-03,  4.22410892e-07,
#         3.26310012e-06,  1.94962916e-06, -5.05000000e-06,  3.00612027e-06,
#        -1.22000000e-07,  3.95240056e-07, -3.45000000e-07,  2.25957299e-06,
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2124, 14)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
for i in df.isna().sum():
    print((i/len(df))*100)
# Out:
# 0.9887005649717515
# 0.9416195856873822
# 0.0
# 0.0
# 0.0
# 0.9887005649717515
# 0.9887005649717515
# 0.0
# 0.0
# 0.0
# 0.9887005649717515
# 0.9887005649717515
# 0.9887005649717515
# 0.9887005649717515

# %%
df['LB'].median()
LB_median = df['LB'].median()
df['LB'].fillna(LB_median, inplace=True) 

df['AC'].median()
AC_median = df['AC'].median()
df['AC'].fillna(AC_median, inplace=True)

df['DS'].median()
DS_median = df['DS'].median()
df['DS'].fillna(DS_median, inplace=True)

df['DP'].median()
DP_median = df['DP'].median()
df['DP'].fillna(DP_median, inplace=True)

df['MLTV'].median()
MLTV_median = df['MLTV'].median()
df['MLTV'].fillna(MLTV_median, inplace=True)

df['Width'].median()
Width_median = df['Width'].median()
df['Width'].fillna(Width_median, inplace=True)

df['Tendency'].median()
Tendency_median = df['Tendency'].median()
df['Tendency'].fillna(Tendency_median, inplace=True)

df['NSP'].median()
NSP_median = df['NSP'].median()
df['NSP'].fillna(NSP_median, inplace=True)

# %%
df.isna().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.338641     0.003205     0.009904     0.004394     0.001897
# std      11.212447     0.004374     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001634     0.000000     0.004486     0.000000
# 75%     140.000000     0.005612     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean      0.000002     0.000174    47.012459     1.364345    10.295650
# std       0.000141     0.000836    18.812403     1.174084    21.212676
# ...

# %%
df.hist()       #outliers
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
df['LB'].quantile(0.75)
# Out:
# 140.0

# %%
def capping(data, columns):
    for col in columns:
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        iqr = q3-q1
    
        lower = q1-(1.5*iqr)
        upper = q3+(1.5*iqr)
        
        df[col] = np.where(df[col] > upper, upper, np.where(df[col] < lower, lower,df[col]))

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.drop(columns=['AC']).columns
# Out:
# Index(['LB', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV',
#        'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
capping(df, df.drop(columns=['AC', 'UC','DS','DL','DP']).columns)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.075970 -0.006840 -0.165894 -0.133809 -0.006033
# AC       -0.075970  1.000000  0.059889  0.071313 -0.093581 -0.033097
# FM       -0.006840  0.059889  1.000000 -0.290553 -0.004149  0.003368
# UC       -0.165894  0.071313 -0.290553  1.000000  0.189737 -0.006958
# DL       -0.133809 -0.093581 -0.004149  0.189737  1.000000  0.058413
# DS       -0.006033 -0.033097  0.003368 -0.006958  0.058413  1.000000
# DP       -0.052772 -0.083350  0.055810  0.070144  0.144631  0.004317
# ASTV      0.285464 -0.240912  0.155798 -0.195204 -0.079118  0.009048
# MSTV     -0.295132  0.196657  0.070412  0.267557  0.502083  0.025435
# ALTV      0.322864 -0.360093 -0.013820 -0.276467 -0.247656 -0.008833
# MLTV     -0.042241 -0.133789 -0.036439 -0.064348 -0.226841 -0.004437
# Width    -0.139983  0.249067  0.164189  0.119583  0.441587  0.044142
# Tendency  0.281144  0.032945  0.000302 -0.070459 -0.023507 -0.015915
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True, cmap='twilight')
# Out:
# <Axes: >

# %%
sns.pairplot(df)
