# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\Akram siddiqui\\documents\\ExcelR\\Data science assignments\\MLR\\ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
pd.get_dummies(data=df,columns= ['Fuel_Type'], dtype=int)
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
df = pd.get_dummies(data=df,columns= ['Fuel_Type'], dtype=int)

# %%
import statsmodels.formula.api as smf     #model building

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              0                 1                 0
# 1    1165              0                 1                 0
# 2    1165              0                 1                 0
# 3    1165              0                 1                 0
# 4    1170              0                 1                 0

# %%
df['Doors'].unique()
# Out:
# array([3, 5, 4, 2], dtype=int64)

# %%
df.dtypes
# Out:
# Price               int64
# Age_08_04           int64
# KM                  int64
# HP                  int64
# Automatic           int64
# cc                  int64
# Doors               int64
# Cylinders           int64
# Gears               int64
# Weight              int64
# Fuel_Type_CNG       int32
# Fuel_Type_Diesel    int32
# Fuel_Type_Petrol    int32
# dtype: object

# %%
model = smf.ols('Cylinders~Price+Age_08_04+KM+HP+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data=df).fit()

# %%
model.params
# Out:
# Intercept           3.000000e+00
# Price              -5.759824e-18
# Age_08_04          -1.175275e-16
# KM                  6.399334e-19
# HP                  3.035766e-17
# Automatic           3.434752e-16
# cc                  7.372575e-18
# Doors              -2.428613e-16
# Gears               6.106227e-16
# Weight             -1.235990e-17
# Fuel_Type_CNG       1.000000e+00
# Fuel_Type_Diesel    1.000000e+00
# Fuel_Type_Petrol    1.000000e+00
# dtype: float64

# %%
model.pvalues
# Out:
# Intercept           0.000000e+00
# Price               4.385423e-12
# Age_08_04           3.693539e-01
# KM                  6.201086e-45
# HP                  7.881786e-01
# Automatic           9.454508e-01
# cc                  1.020724e-02
# Doors               8.488195e-01
# Gears               9.213856e-01
# Weight              7.665755e-01
# Fuel_Type_CNG       0.000000e+00
# Fuel_Type_Diesel    0.000000e+00
# Fuel_Type_Petrol    0.000000e+00
# dtype: float64

# %%
#hp
hp = smf.ols('Cylinders~HP+Price+Age_08_04+KM+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data = df).fit()
hp.pvalues
# Out:
# Intercept           0.000000e+00
# HP                  7.028119e-03
# Price               6.799051e-05
# Age_08_04           9.898322e-01
# KM                  1.385832e-85
# Automatic           9.303026e-01
# cc                  1.360776e-01
# Doors               8.177388e-01
# Gears               9.559653e-01
# Weight              5.558915e-01
# Fuel_Type_CNG       0.000000e+00
# Fuel_Type_Diesel    0.000000e+00
# Fuel_Type_Petrol    0.000000e+00
# dtype: float64

# %%
#cc
cc = smf.ols('Cylinders~cc+Price+Age_08_04+KM+HP+Automatic+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data = df).fit()
cc.pvalues
# Out:
# Intercept           0.000000e+00
# cc                  1.059121e-01
# Price               3.098540e-09
# Age_08_04           3.621933e-01
# KM                  2.138858e-45
# HP                  8.975477e-01
# Automatic           9.374007e-01
# Doors               9.272112e-01
# Gears               8.626081e-01
# Weight              7.798335e-01
# Fuel_Type_CNG       0.000000e+00
# Fuel_Type_Diesel    0.000000e+00
# Fuel_Type_Petrol    0.000000e+00
# dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              0                 1                 0
# 1    1165              0                 1                 0
# 2    1165              0                 1                 0
# 3    1165              0                 1                 0
# 4    1170              0                 1                 0

# %%
data = df.drop(columns=['Cylinders'])
data
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Gears  Weight  \
# 0     13500         23  46986   90          0  2000      3      5    1165
# 1     13750         23  72937   90          0  2000      3      5    1165
# 2     13950         24  41711   90          0  2000      3      5    1165
# 3     14950         26  48000   90          0  2000      3      5    1165
# 4     13750         30  38500   90          0  2000      3      5    1170
# ...     ...        ...    ...  ...        ...   ...    ...    ...     ...
# 1431   7500         69  20544   86          0  1300      3      5    1025
# 1432  10845         72  19000   86          0  1300      3      5    1015
# 1433   8500         71  17016   86          0  1300      3      5    1015
# 1434   7250         70  16916   86          0  1300      3      5    1015
# 1435   6950         76      1  110          0  1600      5      5    1114
#
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
vif = pd.DataFrame()
vif
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'Automatic', 'cc', 'Doors', 'Gears',
#        'Weight', 'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol'],
#       dtype='object')

# %%
vif['Features'] = data.columns
vif
# Out:
#             Features
# 0              Price
# 1          Age_08_04
# 2                 KM
# 3                 HP
# 4          Automatic
# 5                 cc
# 6              Doors
# 7              Gears
# 8             Weight
# 9      Fuel_Type_CNG
# 10  Fuel_Type_Diesel
# 11  Fuel_Type_Petrol

# %%
len(data.columns)
# Out:
# 12

# %%
range(len(data.columns))
# Out:
# range(0, 12)

# %%
df.dtypes
# Out:
# Price               int64
# Age_08_04           int64
# KM                  int64
# HP                  int64
# Automatic           int64
# cc                  int64
# Doors               int64
# Cylinders           int64
# Gears               int64
# Weight              int64
# Fuel_Type_CNG       int32
# Fuel_Type_Diesel    int32
# Fuel_Type_Petrol    int32
# dtype: object

# %%
variance_inflation_factor(data,1)
# Out:
# 4.903089905061446

# %%
[variance_inflation_factor(data,i) for i in range(0,10)]
# Out:
# [7.402383536111805,
#  4.903089905061446,
#  2.2448611077572016,
#  2.369670241855216,
#  1.0972210713080985,
#  1.2242053812578633,
#  1.2183682705005123,
#  1.125169089582293,
#  3.972897969701574,
#  22.869423590994757]

# %%
vif
# Out:
#             Features
# 0              Price
# 1          Age_08_04
# 2                 KM
# 3                 HP
# 4          Automatic
# 5                 cc
# 6              Doors
# 7              Gears
# 8             Weight
# 9      Fuel_Type_CNG
# 10  Fuel_Type_Diesel
# 11  Fuel_Type_Petrol

# %%
vif['VIF'] = [variance_inflation_factor(data,i) for i in range(0,12)]

# %%
vif
# Out:
#             Features          VIF
# 0              Price     7.402384
# 1          Age_08_04     4.903090
# 2                 KM     2.244861
# 3                 HP     2.369670
# 4          Automatic     1.097221
# 5                 cc     1.224205
# 6              Doors     1.218368
# 7              Gears     1.125169
# 8             Weight     3.972898
# 9      Fuel_Type_CNG    22.869424
# 10  Fuel_Type_Diesel   226.849839
# 11  Fuel_Type_Petrol  1579.214272

# %%
#hp
hp = smf.ols('Cylinders~HP+Price+Age_08_04+KM+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data = df).fit()
hp.rsquared
# Out:
# -inf

# %%
#cc
cc = smf.ols('Cylinders~cc+Price+Age_08_04+KM+HP+Automatic+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data = df).fit()
cc.rsquared
# Out:
# -inf

# %%
cc.pvalues
# Out:
# Intercept           0.000000e+00
# cc                  1.059121e-01
# Price               3.098540e-09
# Age_08_04           3.621933e-01
# KM                  2.138858e-45
# HP                  8.975477e-01
# Automatic           9.374007e-01
# Doors               9.272112e-01
# Gears               8.626081e-01
# Weight              7.798335e-01
# Fuel_Type_CNG       0.000000e+00
# Fuel_Type_Diesel    0.000000e+00
# Fuel_Type_Petrol    0.000000e+00
# dtype: float64

# %% [markdown]
# # MODEL VALIDATION TECHNIQUES

# %%
df.head()       #Residual Analysis
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              0                 1                 0
# 1    1165              0                 1                 0
# 2    1165              0                 1                 0
# 3    1165              0                 1                 0
# 4    1170              0                 1                 0

# %%
cc.params
# Out:
# Intercept           3.000000e+00
# cc                  5.529431e-18
# Price              -5.864856e-18
# Age_08_04          -1.422473e-16
# KM                  7.674119e-19
# HP                  1.734723e-17
# Automatic           4.701101e-16
# Doors               1.387779e-16
# Gears               1.276756e-15
# Weight             -1.387779e-17
# Fuel_Type_CNG       1.000000e+00
# Fuel_Type_Diesel    1.000000e+00
# Fuel_Type_Petrol    1.000000e+00
# dtype: float64

# %%
model = smf.ols('Cylinders~HP+Price+Age_08_04+KM+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol',data = df).fit()
model.rsquared
# Out:
# -inf

# %%
#Statsmodel
import statsmodels.api as sm

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              0                 1                 0
# 1    1165              0                 1                 0
# 2    1165              0                 1                 0
# 3    1165              0                 1                 0
# 4    1170              0                 1                 0

# %%
model.fittedvalues
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 1431    4.0
# 1432    4.0
# 1433    4.0
# 1434    4.0
# 1435    4.0
# Length: 1436, dtype: float64

# %%
model.resid
# Out:
# 0       4.041212e-14
# 1       1.065814e-14
# 2       4.884981e-14
# 3       4.574119e-14
# 4       5.195844e-14
#             ...
# 1431    4.529710e-14
# 1432    6.084022e-14
# 1433    5.329071e-14
# 1434    4.796163e-14
# 1435    5.861978e-14
# Length: 1436, dtype: float64

# %%
model.params
# Out:
# Intercept           3.000000e+00
# HP                  3.963843e-16
# Price              -4.282599e-18
# Age_08_04           2.168404e-18
# KM                  1.199399e-18
# Automatic           5.707240e-16
# cc                  5.556536e-18
# Doors               3.816392e-16
# Gears               4.440892e-16
# Weight             -3.187554e-17
# Fuel_Type_CNG       1.000000e+00
# Fuel_Type_Diesel    1.000000e+00
# Fuel_Type_Petrol    1.000000e+00
# dtype: float64

# %% [markdown]
# ###### Q-Q Plot

# %%
sm.qqplot(model.resid, line='q');

# %%
np.argmax(model.resid), np.max(model.resid)
# Out:
# (109, 1.7719159473017498e-13)

# %%
#Residual plot of Homoscedasticity
model.fittedvalues        #predicted values
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 1431    4.0
# 1432    4.0
# 1433    4.0
# 1434    4.0
# 1435    4.0
# Length: 1436, dtype: float64

# %%
model.resid      #errors
# Out:
# 0       4.041212e-14
# 1       1.065814e-14
# 2       4.884981e-14
# 3       4.574119e-14
# 4       5.195844e-14
#             ...
# 1431    4.529710e-14
# 1432    6.084022e-14
# 1433    5.329071e-14
# 1434    4.796163e-14
# 1435    5.861978e-14
# Length: 1436, dtype: float64

# %%
plt.scatter(model.fittedvalues, model.resid)
plt.xlabel('Predicted Values')
plt.ylabel('Errors')
plt.title('Constant Variance')
# Out:
# Text(0.5, 1.0, 'Constant Variance')

# %%
sns.set_style('darkgrid')

# %%
plt.scatter(model.fittedvalues, model.resid)
plt.xlabel('Predicted')
plt.ylabel('Errors')
# Out:
# Text(189.80555555555557, 0.5, 'Errors')

# %%
#Residual VS Regressor
sm.graphics.plot_regress_exog(model,'cc');

# %%
sm.graphics.plot_regress_exog(model,'Weight');

# %% [markdown]
# ## MODEL DELETION TECHNIQUES

# %% [markdown]
# #### Cook's Distance

# %% [markdown]
# ###### -Detecting influencers and outliers

# %%
model

# %%
#Find the influence data
inf = model.get_influence()

#Calculate the cooks distance
c,p = inf.cooks_distance

# %%
c
# Out:
# array([6.34663029e-04, 3.66507068e-05, 8.83739181e-04, ...,
#        5.08399136e-04, 4.35428631e-04, 1.54818119e-03])

# %%
# Cook's distance plot
plt.stem(c)
plt.xlabel('Index')
plt.ylabel('Cooks Distance')
# Out:
# Text(1335.4375, 0.5, 'Cooks Distance')

# %%
np.argmax(c), np.max(c)
# Out:
# (80, 2.4378689556080633)

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              0                 1                 0
# 1    1165              0                 1                 0
# 2    1165              0                 1                 0
# 3    1165              0                 1                 0
# 4    1170              0                 1                 0

# %%
df.iloc[[80]]
# Out:
#     Price  Age_08_04     KM   HP  Automatic     cc  Doors  Cylinders  Gears  \
# 80  18950         25  20019  110          1  16000      5          4      5
#
#     Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 80    1180              0                 0                 1

# %%
df['Cooks Distance'] = c

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
df[df['Cooks Distance'] > 1]
# Out:
#     Price  Age_08_04     KM   HP  Automatic     cc  Doors  Cylinders  Gears  \
# 80  18950         25  20019  110          1  16000      5          4      5
#
#     Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Cooks Distance
# 80    1180              0                 0                 1        2.437869

# %%
sns.scatterplot(data = df ,x = 'cc' , y = 'Weight')
# Out:
# <Axes: title={'center': 'CCPR Plot'}, xlabel='Index', ylabel='Cooks Distance'>

# %% [markdown]
# #### Improving the model

# %%
df.drop(index=80,inplace=True)

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
#reset the index

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  \
# 0         0  13500         23  46986   90          0  2000      3          4
# 1         1  13750         23  72937   90          0  2000      3          4
# 2         2  13950         24  41711   90          0  2000      3          4
# 3         3  14950         26  48000   90          0  2000      3          4
# 4         4  13750         30  38500   90          0  2000      3          4
# ...     ...    ...        ...    ...  ...        ...   ...    ...        ...
# 1430   1431   7500         69  20544   86          0  1300      3          4
# 1431   1432  10845         72  19000   86          0  1300      3          4
# 1432   1433   8500         71  17016   86          0  1300      3          4
# 1433   1434   7250         70  16916   86          0  1300      3          4
# 1434   1435   6950         76      1  110          0  1600      5          4
#
# ...

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1430   7500         69  20544   86          0  1300      3          4      5
# 1431  10845         72  19000   86          0  1300      3          4      5
# 1432   8500         71  17016   86          0  1300      3          4      5
# 1433   7250         70  16916   86          0  1300      3          4      5
# 1434   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
final_model = smf.ols('Cylinders~HP+Price+Age_08_04+KM+Automatic+cc+Doors+Gears+Weight+Fuel_Type_CNG+Fuel_Type_Diesel+Fuel_Type_Petrol', data = df).fit()

# %%
final_model.rsquared
# Out:
# -inf

# %% [markdown]
# # prediction for new records

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Cooks Distance
# 0    1165              0                 1                 0        0.000635
# 1    1165              0                 1                 0        0.000037
# 2    1165              0                 1                 0        0.000884
# 3    1165              0                 1                 0        0.000640
# 4    1170              0                 1                 0        0.000947

# %%
df.tail()
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 1430   7500         69  20544   86          0  1300      3          4      5
# 1431  10845         72  19000   86          0  1300      3          4      5
# 1432   8500         71  17016   86          0  1300      3          4      5
# 1433   7250         70  16916   86          0  1300      3          4      5
# 1434   6950         76      1  110          0  1600      5          4      5
#
#       Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 1430    1025              0                 0                 1
# 1431    1015              0                 0                 1
# 1432    1015              0                 0                 1
# 1433    1015              0                 0                 1
# 1434    1114              0                 0                 1
#
#       Cooks Distance
# 1430        0.000362
# 1431        0.000941
# 1432        0.000508
# 1433        0.000435
# ...

# %%
test = pd.DataFrame({
    'KM' : [40000,50000,54000,60000,70000],
    'HP' : [92.6,85.63,75,78,65],
    'Price' : [1710,1120,1850,1500,2000],
    'Age_08_04' : [23,34,56,76,36],
    'Automatic' : [0,0,0,0,0],
    'cc' : [1300,1400,1600,1800,2000],
    'Doors' : [3,3,3,3,3],
    'Gears' : [5,5,5,5,5],
    'Weight': [1025,1015,1170,1165,1114],
    'Fuel_Type_CNG' : [0,1,0,1,0],
    'Fuel_Type_Diesel' : [0,1,0,1,0],	
    'Fuel_Type_Petrol' : [0,1,0,1,0],
})
test
# Out:
#       KM     HP  Price  Age_08_04  Automatic    cc  Doors  Gears  Weight  \
# 0  40000  92.60   1710         23          0  1300      3      5    1025
# 1  50000  85.63   1120         34          0  1400      3      5    1015
# 2  54000  75.00   1850         56          0  1600      3      5    1170
# 3  60000  78.00   1500         76          0  1800      3      5    1165
# 4  70000  65.00   2000         36          0  2000      3      5    1114
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 0                 0
# 1              1                 1                 1
# 2              0                 0                 0
# 3              1                 1                 1
# 4              0                 0                 0

# %%
final_model.params
# Out:
# Intercept           3.000000e+00
# HP                 -1.072276e-16
# Price              -1.423015e-18
# Age_08_04          -1.231654e-16
# KM                 -1.528471e-18
# Automatic           7.077672e-16
# cc                 -9.324139e-18
# Doors              -4.614364e-16
# Gears              -2.775558e-16
# Weight              2.103352e-17
# Fuel_Type_CNG       1.000000e+00
# Fuel_Type_Diesel    1.000000e+00
# Fuel_Type_Petrol    1.000000e+00
# dtype: float64

# %%
final_model.predict(test)
# Out:
# 0    3.0
# 1    6.0
# 2    3.0
# 3    6.0
# 4    3.0
# dtype: float64

# %% [markdown]
# # Interview Questions

# %% [markdown]
# ## 1.What is Normalization & Standardization and how is it helpful?

# %% [markdown]
#  Normalization: Scales data to a range 0 to 1 and Useful when features have different scales but a fixed range is needed (e.g., pixel data).
#
# Standardization: Scales data to have a mean of 0 and a standard deviation of 1 and Best when data follows a normal distribution or for algorithms sensitive to variance (e.g., Logistic Regression).
#
# It helpful for:
#
# 1.Improves model performance by balancing feature scales.
#
# 2.Speeds up optimization (e.g., gradient descent).
#
# 3.Prevents dominance of large-scale features.
#
# 4.Enhances fairness and interpretability.

# %% [markdown]
# ## 2.What techniques can be used to address multicollinearity in multiple linear regression?

# %% [markdown]
# 1.Remove Highly Correlated Predictors i.e. Drop one of the variables that show high correlation.
#
# 2.Variance Inflation Factor (VIF) Identify and remove predictors with high VIF values (typically > 5 or 10).
#
# 3.Regularization: Use techniques like Ridge Regression or Lasso Regression to penalize and reduce the impact of multicollinearity.
#
# 4.Principal Component Analysis (PCA): Transform correlated predictors into a smaller set of uncorrelated components.
#
# 5.Combine Variables: Combine correlated variables into a single feature (e.g., averaging or summing them).
#
# 6.Increase Sample Size: Collect more data to reduce the impact of multicollinearity on model estimation.
